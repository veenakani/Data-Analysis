# %%
import pandas as pd

# %%
dataset=pd.read_csv("PrePlacemnt.csv")

# %%
dataset
# Out:
#      Unnamed: 0  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# 0             0      1      M  67.00   Others  91.00   Others  Commerce
# 1             1      2      M  79.33  Central  78.33   Others   Science
# 2             2      3      M  65.00  Central  68.00  Central      Arts
# 3             3      4      M  56.00  Central  52.00  Central   Science
# 4             4      5      M  85.80  Central  73.60  Central  Commerce
# ..          ...    ...    ...    ...      ...    ...      ...       ...
# 210         210    211      M  80.60   Others  82.00   Others  Commerce
# 211         211    212      M  58.00   Others  60.00   Others   Science
# 212         212    213      M  67.00   Others  67.00   Others  Commerce
# 213         213    214      F  74.00   Others  66.00   Others  Commerce
# 214         214    215      M  62.00  Central  58.00   Others   Science
#
#      degree_p   degree_t workex  etest_p specialisation  mba_p      status  \
# 0       58.00   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed
# 1       77.48   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed
# 2       64.00  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed
# 3       52.00   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed
# 4       73.30  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed
# ..        ...        ...    ...      ...            ...    ...         ...
# 210     77.60  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed
# 211     72.00   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed
# 212     73.00  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed
# 213     58.00  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed
# 214     53.00  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed
#
#        salary
# 0    270000.0
# 1    200000.0
# 2    250000.0
# 3         0.0
# 4    425000.0
# ..        ...
# 210  400000.0
# 211  275000.0
# 212  295000.0
# 213  204000.0
# 214       0.0
#
# [215 rows x 16 columns]

# %%
print("The Number of Row:",dataset.shape[0])
print("The Number of Coulmn",dataset.shape[1])
# Out:
# The Number of Row: 215
# The Number of Coulmn 16

# %%
dataset.shape
# Out:
# (215, 16)

# %%
#Bivarite Analysis
#Distribution Plot
import seaborn as sb
import matplotlib.pyplot as plt
sb.jointplot(x='ssc_p',y='salary',data=dataset)
plt.show()

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset,kind='hex')
plt.show()

# %%
sb.jointplot(x='ssc_p',y='salary',data=dataset,kind='kde')
plt.show()

# %%
sb.pairplot(dataset,hue ='gender',diag_kind='kde',kind='scatter', palette='husl')
plt.show()

# %%
#for Categorical data
sb.stripplot(x='ssc_b',y="ssc_p",data=dataset)
plt.show()

# %%
sb.stripplot(x='gender',y="ssc_p",data=dataset,jitter=True)
plt.show()

# %%
sb.swarmplot(x='gender',y="ssc_p",data=dataset)
plt.show()

# %%
#Distribution Observation
sb.violinplot(x="gender",y="ssc_p",data=dataset)
plt.show()

# %%
sb.violinplot(x="ssc_b",y="ssc_p",data=dataset,hue="gender")
plt.show()

# %%
sb.boxplot(x="ssc_b",y="ssc_p",data=dataset,hue="gender")
plt.show()

# %%
sb.barplot(x="ssc_b",y="ssc_p",data=dataset,hue="gender")
plt.show()

# %%
sb.countplot(x="ssc_b",data=dataset,hue="gender")
plt.show()

# %%
sb.pointplot(x="ssc_p",y="hsc_b",data=dataset,hue="gender")
plt.show()

# %%
sb.boxplot(data=dataset,orient='h')
plt.show()

# %%
#factor Plot
from matplotlib import pyplot as plt
df=sb.load_dataset('exercise')
sb.factorplot(x="time",y="pulse",hue="kind",kind="violin",col="diet",data=df);
plt.show()
# Out:
# C:\Users\CP\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#regplot
df=sb.load_dataset('tips')
sb.regplot(x="total_bill",y='tip',data=df)
sb.lmplot(x="total_bill",y='tip',data=df)
plt.show()

# %%
df=sb.load_dataset('anscombe')
sb.lmplot(x="x",y='y',data=df.query("dataset=='II'"))
plt.show()

# %%
df=sb.load_dataset('anscombe')
sb.lmplot(x="x",y='y',data=df.query("dataset=='II'"),order=2)
plt.show()

# %%
df=sb.load_dataset('tips')
g=sb.FacetGrid(df,col='time')
g.map(plt.hist,"tip")
plt.show()

# %%
df=sb.load_dataset('iris')
g=sb.PairGrid(df)
g.map(plt.scatter)
plt.show()
